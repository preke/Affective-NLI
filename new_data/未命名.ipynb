# %%
import pandas as pd
df = pd.read_csv('Friends_A_with_role_0.25_0_test.tsv', sep='\t')
df.head()
# Out:
#    Unnamed: 0        scene_id  \
# 0         592  04_e19_c05(3)
# 1          76  04_e18_c10(0)
# 2         193  01_e18_c02(0)
# 3         482  04_e17_c05(0)
# 4           8  03_e04_c04(0)
#
#                                             raw_text     characters  \
# 0  [['Phoebe', " I don't know. Ooh! Ooh! Look it!...       Chandler
# 1  [['Joey', ' Dude, I am sorry about what I said...       Chandler
# 2  [['Rachel Green', " Oh, no-no-no-no-no-no, tha...  Chandler Bing
# 3  [['Alice', ' (entering) Oh-oh, Phoebe!'], ['Ph...          Frank
# 4  [['Phoebe', " Oh, it's your audition from this...         Rachel
#
#                                     affective_prompt  \
# 0          First, the emotion of others is neutral,
# 1  First, the emotion of others is neutral, Chand...
# 2  First, the emotion of others is neutral, the e...
# 3  First, the emotion of others is neutral, the e...
# 4          First, the emotion of others is neutral,
#
# ...

# %%
df['sent_and_prompt'][0]
# Out:
# "Others :  I don't know. Ooh! Ooh! Look it! (She fans out the trick deck.) Ah-ha!, ; First, the emotion of others is neutral, "
